# %% [markdown]
# <a href="https://colab.research.google.com/github/chibuikemn/3D_Scan/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-2kzrmnjx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-2kzrmnjx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=75607d5c63889547b07d9420a86b43010e69198c9be70c5969d1410915cfc993
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fpkfenj6/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    #Residual Block1
    h2 = self.linear2(h1).relu()
    h2 =h2+h1
    #Residual Block2
    h3 = self.linear3(h2).relu()
    h3 =h3+h2
    #output layer
    out = self.linear4(h3)
    return out

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.541485, train error 58.78,  val loss 1.634397, percent error 64.50
# Epoch     1, train loss 1.271839, train error 46.10,  val loss 1.395640, percent error 53.60
# Epoch     2, train loss 1.084378, train error 39.88,  val loss 1.266757, percent error 49.50
# Epoch     3, train loss 0.953453, train error 34.50,  val loss 1.187855, percent error 46.20
# Epoch     4, train loss 0.841432, train error 30.25,  val loss 1.123403, percent error 43.30
# Epoch     5, train loss 0.738610, train error 26.35,  val loss 1.079653, percent error 41.00
# Epoch     6, train loss 0.672698, train error 24.28,  val loss 1.102579, percent error 40.60
# Epoch     7, train loss 0.641094, train error 23.00,  val loss 1.124623, percent error 40.00
# Epoch     8, train loss 0.533416, train error 19.00,  val loss 1.081825, percent error 39.20
# Epoch     9, train loss 0.480306, train error 16.70,  val loss 1.080297, percent error 39.30
# Epoch    10, train loss 0.488815, train error 17.45,  val loss 1.187295, percent error 41.30
# Epoch    11, train loss 0.402785, train error 14.25,  val loss 1.203735, percent error 38.90
# Epoch    12, train loss 0.372525, train error 13.30,  val loss 1.222517, percent error 40.20
# Epoch    13, train loss 0.324723, train error 11.00,  val loss 1.288928, percent error 40.70
# Epoch    14, train loss 0.259358, train error 8.32,  val loss 1.223730, percent error 38.60
# Epoch    15, train loss 0.232234, train error 7.65,  val loss 1.226297, percent error 37.90
# Epoch    16, train loss 0.238227, train error 8.05,  val loss 1.415445, percent error 38.40
# Epoch    17, train loss 0.205556, train error 6.45,  val loss 1.393941, percent error 38.80
# Epoch    18, train loss 0.186689, train error 5.60,  val loss 1.443598, percent error 36.60
# Epoch    19, train loss 0.244827, train error 8.43,  val loss 1.595697, percent error 37.40
# Epoch    20, train loss 0.082277, train error 1.82,  val loss 1.345354, percent error 33.70
# Epoch    21, train loss 0.040344, train error 0.10,  val loss 1.320644, percent error 34.90
# Epoch    22, train loss 0.030127, train error 0.05,  val loss 1.367614, percent error 34.80
# Epoch    23, train loss 0.024870, train error 0.00,  val loss 1.403223, percent error 34.10
# Epoch    24, train loss 0.020945, train error 0.00,  val loss 1.424899, percent error 33.80
# Epoch    25, train loss 0.018793, train error 0.00,  val loss 1.445870, percent error 33.80
# Epoch    26, train loss 0.016864, train error 0.00,  val loss 1.485621, percent error 33.90
# Epoch    27, train loss 0.015253, train error 0.00,  val loss 1.488655, percent error 34.00
# Epoch    28, train loss 0.014167, train error 0.00,  val loss 1.508465, percent error 33.80
# Epoch    29, train loss 0.012737, train error 0.00,  val loss 1.533117, percent error 34.00
# Epoch    30, train loss 0.011973, train error 0.00,  val loss 1.538686, percent error 33.70
# Epoch    31, train loss 0.011304, train error 0.00,  val loss 1.559308, percent error 33.80
# Epoch    32, train loss 0.010367, train error 0.00,  val loss 1.574619, percent error 33.70
# Epoch    33, train loss 0.009778, train error 0.00,  val loss 1.586143, percent error 33.70
# Epoch    34, train loss 0.009243, train error 0.00,  val loss 1.602340, percent error 34.20
# Epoch    35, train loss 0.008778, train error 0.00,  val loss 1.616881, percent error 33.40
# Epoch    36, train loss 0.008271, train error 0.00,  val loss 1.624013, percent error 33.50
# Epoch    37, train loss 0.007888, train error 0.00,  val loss 1.631007, percent error 33.50
# Epoch    38, train loss 0.007467, train error 0.00,  val loss 1.647380, percent error 33.80
# Epoch    39, train loss 0.007153, train error 0.00,  val loss 1.658044, percent error 33.80
# Epoch    40, train loss 0.006957, train error 0.00,  val loss 1.664382, percent error 33.90
# Epoch    41, train loss 0.006797, train error 0.00,  val loss 1.669058, percent error 33.70
# Epoch    42, train loss 0.006661, train error 0.00,  val loss 1.672705, percent error 33.60
# Epoch    43, train loss 0.006531, train error 0.00,  val loss 1.678774, percent error 33.60
# Epoch    44, train loss 0.006402, train error 0.00,  val loss 1.682946, percent error 33.60
# Epoch    45, train loss 0.006265, train error 0.00,  val loss 1.687512, percent error 33.60
# Epoch    46, train loss 0.006147, train error 0.00,  val loss 1.692568, percent error 33.60
# Epoch    47, train loss 0.006029, train error 0.00,  val loss 1.695891, percent error 33.50
# Epoch    48, train loss 0.005913, train error 0.00,  val loss 1.700478, percent error 33.50
# Epoch    49, train loss 0.005804, train error 0.00,  val loss 1.706974, percent error 33.60
# Epoch    50, train loss 0.005699, train error 0.00,  val loss 1.709840, percent error 33.60
# Epoch    51, train loss 0.005594, train error 0.00,  val loss 1.713459, percent error 33.70
# Epoch    52, train loss 0.005494, train error 0.00,  val loss 1.718555, percent error 33.70
# Epoch    53, train loss 0.005397, train error 0.00,  val loss 1.722502, percent error 33.40
# Epoch    54, train loss 0.005305, train error 0.00,  val loss 1.727229, percent error 33.70
# Epoch    55, train loss 0.005215, train error 0.00,  val loss 1.730230, percent error 33.60
# Epoch    56, train loss 0.005130, train error 0.00,  val loss 1.733693, percent error 33.50
# Epoch    57, train loss 0.005043, train error 0.00,  val loss 1.739512, percent error 33.70
# Epoch    58, train loss 0.004960, train error 0.00,  val loss 1.741910, percent error 33.50
# Epoch    59, train loss 0.004885, train error 0.00,  val loss 1.746411, percent error 33.60
# Epoch    60, train loss 0.004840, train error 0.00,  val loss 1.747754, percent error 33.40
# Epoch    61, train loss 0.004801, train error 0.00,  val loss 1.750319, percent error 33.40
# Epoch    62, train loss 0.004763, train error 0.00,  val loss 1.752451, percent error 33.30
# Epoch    63, train loss 0.004727, train error 0.00,  val loss 1.754256, percent error 33.60
# Epoch    64, train loss 0.004689, train error 0.00,  val loss 1.756441, percent error 33.60
# Epoch    65, train loss 0.004652, train error 0.00,  val loss 1.758011, percent error 33.50
# Epoch    66, train loss 0.004617, train error 0.00,  val loss 1.759865, percent error 33.60
# Epoch    67, train loss 0.004582, train error 0.00,  val loss 1.761247, percent error 33.60
# Epoch    68, train loss 0.004547, train error 0.00,  val loss 1.763531, percent error 33.60
# Epoch    69, train loss 0.004514, train error 0.00,  val loss 1.765504, percent error 33.60
# Epoch    70, train loss 0.004479, train error 0.00,  val loss 1.766719, percent error 33.50
# Epoch    71, train loss 0.004446, train error 0.00,  val loss 1.768671, percent error 33.50
# Epoch    72, train loss 0.004413, train error 0.00,  val loss 1.770621, percent error 33.60
# Epoch    73, train loss 0.004381, train error 0.00,  val loss 1.772220, percent error 33.70
# Epoch    74, train loss 0.004349, train error 0.00,  val loss 1.774105, percent error 33.60
# Epoch    75, train loss 0.004317, train error 0.00,  val loss 1.775401, percent error 33.60
# Epoch    76, train loss 0.004286, train error 0.00,  val loss 1.777008, percent error 33.60
# Epoch    77, train loss 0.004255, train error 0.00,  val loss 1.778629, percent error 33.50
# Epoch    78, train loss 0.004225, train error 0.00,  val loss 1.780512, percent error 33.50
# Epoch    79, train loss 0.004195, train error 0.00,  val loss 1.782505, percent error 33.40
# Epoch    80, train loss 0.004180, train error 0.00,  val loss 1.782991, percent error 33.50
# Epoch    81, train loss 0.004165, train error 0.00,  val loss 1.783782, percent error 33.50
# Epoch    82, train loss 0.004150, train error 0.00,  val loss 1.784551, percent error 33.50
# Epoch    83, train loss 0.004135, train error 0.00,  val loss 1.785494, percent error 33.50
# Epoch    84, train loss 0.004121, train error 0.00,  val loss 1.786165, percent error 33.60
# Epoch    85, train loss 0.004107, train error 0.00,  val loss 1.787013, percent error 33.60
# Epoch    86, train loss 0.004092, train error 0.00,  val loss 1.787822, percent error 33.50
# Epoch    87, train loss 0.004078, train error 0.00,  val loss 1.788499, percent error 33.50
# Epoch    88, train loss 0.004064, train error 0.00,  val loss 1.789461, percent error 33.40
# Epoch    89, train loss 0.004050, train error 0.00,  val loss 1.790325, percent error 33.60
# Epoch    90, train loss 0.004037, train error 0.00,  val loss 1.790729, percent error 33.40
# Epoch    91, train loss 0.004023, train error 0.00,  val loss 1.791720, percent error 33.40
# Epoch    92, train loss 0.004009, train error 0.00,  val loss 1.792606, percent error 33.40
# Epoch    93, train loss 0.003996, train error 0.00,  val loss 1.793132, percent error 33.40
# Epoch    94, train loss 0.003982, train error 0.00,  val loss 1.793914, percent error 33.50
# Epoch    95, train loss 0.003969, train error 0.00,  val loss 1.794338, percent error 33.40
# Epoch    96, train loss 0.003955, train error 0.00,  val loss 1.795447, percent error 33.50
# Epoch    97, train loss 0.003942, train error 0.00,  val loss 1.795992, percent error 33.60
# Epoch    98, train loss 0.003929, train error 0.00,  val loss 1.797150, percent error 33.70
# Epoch    99, train loss 0.003916, train error 0.00,  val loss 1.797557, percent error 33.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
